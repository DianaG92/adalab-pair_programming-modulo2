# %% [markdown]
# EJERCICIOS DE API´s

# %%
# Ejercicio 1

import pandas as pd
import requests
import re

pd.set_option('display.max_columns', None)

# %%
def llamar_api(url):
    
    llamada = requests.get(url)
    
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")
    
    if llamada.status_code != 200:
        print(f"El motivo por el que la llamada falló es {llamada.reason} {llamada.text}")
    else:
        return llamada.json()

# %%
url_energia = f"https://apidatos.ree.es/es/datos/generacion/evolucion-renovable-no-renovable?start_date=2021-01-01T00:00&end_date=2022-12-31T23:59&time_trunc=month"

resultados_energia = llamar_api(url_energia)
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200

# %%
resultados_energia
# Out:
# {'data': {'type': 'Evolución de la generación renovable/no renovable',
#   'id': 'gen2',
#   'attributes': {'title': 'Evolución de la generación renovable/no renovable',
#    'last-update': '2022-01-11T09:21:30.000+01:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'HIT',
#     'expireAt': '2024-05-21T09:16:40'}}},
#  'included': [{'type': 'Renovable',
#    'id': '10299',
#    'groupId': None,
#    'attributes': {'title': 'Renovable',
#     'description': 'Energía renovable: incluye hidráulica, hidroeólica, eólica, solar fotovoltaica, solar térmica, otras renovables y residuos renovables.',
#     'color': '#92d050',
#     'type': 'Renovable',
#     'magnitude': None,
#     'composite': False,
#     'last-update': '2022-01-11T09:21:30.000+01:00',
#     'values': [{'value': 12561066.857,
#       'percentage': 0.5167998931450627,
#       'datetime': '2021-01-01T00:00:00.000+01:00'},
#      {'value': 12359937.817,
#       'percentage': 0.5848258664348669,
#       'datetime': '2021-02-01T00:00:00.000+01:00'},
#      {'value': 11799986.558,
#       'percentage': 0.5340039564251576,
#       'datetime': '2021-03-01T00:00:00.000+01:00'},
#      {'value': 9240646.799,
#       'percentage': 0.46434560693441257,
#       'datetime': '2021-04-01T00:00:00.000+02:00'},
#      {'value': 10433361.657,
#       'percentage': 0.5096534842191431,
#       'datetime': '2021-05-01T00:00:00.000+02:00'},
#      {'value': 9287872.5465,
#       'percentage': 0.46757802135965587,
#       'datetime': '2021-06-01T00:00:00.000+02:00'},
#      {'value': 10377789.4405,
#       'percentage': 0.4625349408292119,
#       'datetime': '2021-07-01T00:00:00.000+02:00'},
#      {'value': 9182780.5875,
#       'percentage': 0.4254195166839051,
#       'datetime': '2021-08-01T00:00:00.000+02:00'},
#      {'value': 7472118.4275,
#       'percentage': 0.36116612797192604,
#       'datetime': '2021-09-01T00:00:00.000+02:00'},
#      {'value': 7991904.017,
#       'percentage': 0.387305195401862,
#       'datetime': '2021-10-01T00:00:00.000+02:00'},
#      {'value': 9657319.8605,
#       'percentage': 0.4195606217383241,
#       'datetime': '2021-11-01T00:00:00.000+01:00'},
#      {'value': 11094361.7425,
#       'percentage': 0.46467984184944006,
#       'datetime': '2021-12-01T00:00:00.000+01:00'},
#      {'value': 9750044.556,
#       'percentage': 0.40119784717736745,
#       'datetime': '2022-01-01T00:00:00.000+01:00'},
#      {'value': 8238462.641,
#       'percentage': 0.39006533302518265,
#       'datetime': '2022-02-01T00:00:00.000+01:00'},
#      {'value': 10388479.6225,
#       'percentage': 0.45624098101660193,
#       'datetime': '2022-03-01T00:00:00.000+01:00'},
#      {'value': 10958349.461,
#       'percentage': 0.503310930003355,
#       'datetime': '2022-04-01T00:00:00.000+02:00'},
#      {'value': 11064994.4845,
#       'percentage': 0.5016206994793222,
#       'datetime': '2022-05-01T00:00:00.000+02:00'},
#      {'value': 9257173.325,
#       'percentage': 0.3980394873694197,
#       'datetime': '2022-06-01T00:00:00.000+02:00'},
#      {'value': 10159211.0035,
#       'percentage': 0.3844536804847089,
#       'datetime': '2022-07-01T00:00:00.000+02:00'},
#      {'value': 9548124.8885,
#       'percentage': 0.3776067902432436,
#       'datetime': '2022-08-01T00:00:00.000+02:00'},
#      {'value': 8886428.786,
#       'percentage': 0.3754901450968354,
#       'datetime': '2022-09-01T00:00:00.000+02:00'},
#      {'value': 8453289.591,
#       'percentage': 0.3849991888910192,
#       'datetime': '2022-10-01T00:00:00.000+02:00'},
#      {'value': 10074175.2865,
#       'percentage': 0.46807374016201697,
#       'datetime': '2022-11-01T00:00:00.000+01:00'},
#      {'value': 9916477.1215,
#       'percentage': 0.4460698454803019,
#       'datetime': '2022-12-01T00:00:00.000+01:00'}]}},
#   {'type': 'No renovable',
#    'id': '10298',
#    'groupId': None,
#    'attributes': {'title': 'No renovable',
#     'description': None,
#     'color': '#666666',
#     'type': 'No renovable',
#     'magnitude': None,
#     'composite': False,
#     'last-update': '2022-01-11T09:21:29.000+01:00',
#     'values': [{'value': 11744408.093,
#       'percentage': 0.4832001068549372,
#       'datetime': '2021-01-01T00:00:00.000+01:00'},
#      {'value': 8774451.967,
#       'percentage': 0.41517413356513305,
#       'datetime': '2021-02-01T00:00:00.000+01:00'},
#      {'value': 10297202.828,
#       'percentage': 0.46599604357484237,
#       'datetime': '2021-03-01T00:00:00.000+01:00'},
#      {'value': 10659717.63,
#       'percentage': 0.5356543930655874,
#       'datetime': '2021-04-01T00:00:00.000+02:00'},
#      {'value': 10038119.418,
#       'percentage': 0.49034651578085686,
#       'datetime': '2021-05-01T00:00:00.000+02:00'},
#      {'value': 10575919.4245,
#       'percentage': 0.532421978640344,
#       'datetime': '2021-06-01T00:00:00.000+02:00'},
#      {'value': 12058979.1675,
#       'percentage': 0.537465059170788,
#       'datetime': '2021-07-01T00:00:00.000+02:00'},
#      {'value': 12402455.2265,
#       'percentage': 0.5745804833160948,
#       'datetime': '2021-08-01T00:00:00.000+02:00'},
#      {'value': 13216749.7935,
#       'percentage': 0.638833872028074,
#       'datetime': '2021-09-01T00:00:00.000+02:00'},
#      {'value': 12642737.893,
#       'percentage': 0.612694804598138,
#       'datetime': '2021-10-01T00:00:00.000+02:00'},
#      {'value': 13360378.5605,
#       'percentage': 0.5804393782616759,
#       'datetime': '2021-11-01T00:00:00.000+01:00'},
#      {'value': 12780919.1355,
#       'percentage': 0.53532015815056,
#       'datetime': '2021-12-01T00:00:00.000+01:00'},
#      {'value': 14552290.625,
#       'percentage': 0.5988021528226325,
#       'datetime': '2022-01-01T00:00:00.000+01:00'},
#      {'value': 12882262.385,
#       'percentage': 0.6099346669748174,
#       'datetime': '2022-02-01T00:00:00.000+01:00'},
#      {'value': 12381240.8865,
#       'percentage': 0.5437590189833981,
#       'datetime': '2022-03-01T00:00:00.000+01:00'},
#      {'value': 10814174.853,
#       'percentage': 0.49668906999664497,
#       'datetime': '2022-04-01T00:00:00.000+02:00'},
#      {'value': 10993494.1225,
#       'percentage': 0.4983793005206778,
#       'datetime': '2022-05-01T00:00:00.000+02:00'},
#      {'value': 13999748.711,
#       'percentage': 0.6019605126305804,
#       'datetime': '2022-06-01T00:00:00.000+02:00'},
#      {'value': 16265847.5125,
#       'percentage': 0.615546319515291,
#       'datetime': '2022-07-01T00:00:00.000+02:00'},
#      {'value': 15737768.0965,
#       'percentage': 0.6223932097567564,
#       'datetime': '2022-08-01T00:00:00.000+02:00'},
#      {'value': 14779781.638,
#       'percentage': 0.6245098549031645,
#       'datetime': '2022-09-01T00:00:00.000+02:00'},
#      {'value': 13503353.007,
#       'percentage': 0.6150008111089809,
#       'datetime': '2022-10-01T00:00:00.000+02:00'},
#      {'value': 11448449.0825,
#       'percentage': 0.531926259837983,
#       'datetime': '2022-11-01T00:00:00.000+01:00'},
#      {'value': 12314295.0815,
#       'percentage': 0.5539301545196981,
#       'datetime': '2022-12-01T00:00:00.000+01:00'}]}}]}

# %%
import pandas as pd

if resultados_energia:
    diccionario_energia = {"tipo_energia": [], "tipo_generacion": [], "fecha": [], "valor": []}
    
    for energia in resultados_energia["data"]:
        diccionario_energia["tipo_energia"].append(energia["attributes"]["description"])
        diccionario_energia["tipo_generacion"].append(energia["type"])
        diccionario_energia["fecha"].append(energia["attributes"]["datetime"])
        diccionario_energia["valor"].append(energia["attributes"]["value"])
        
    df_energia = pd.DataFrame(diccionario_energia)
    
    print(df_energia.head())
    
else:
    print("No se pudo obtener la información solicitada.")

# %% [markdown]
# AÑADO ESTA PARTE NUEVA AL CÓDIGO
#
# - Falta modificar el tipo de energía

# %%
import pandas as pd

tipos_energia = []
tipos_generacion = []
fechas = []
valores = []

for item in resultados_energia['included']:
    tipo_energia = item['attributes']['title']
    tipo_generacion = item['type']
    
    for value in item['attributes']['values']:
        fecha = value['datetime']
        valor = value['value']
        
        tipos_energia.append(tipo_energia)
        tipos_generacion.append(tipo_generacion)
        fechas.append(fecha)
        valores.append(valor)

df_energia = pd.DataFrame({
    'Tipo de Energía': tipos_energia,
    'Tipo de Generación': tipos_generacion,
    'Fecha': fechas,
    'Valor': valores
})

df_energia.head(5)
# Out:
#   Tipo de Energía Tipo de Generación                          Fecha  \
# 0       Renovable          Renovable  2021-01-01T00:00:00.000+01:00
# 1       Renovable          Renovable  2021-02-01T00:00:00.000+01:00
# 2       Renovable          Renovable  2021-03-01T00:00:00.000+01:00
# 3       Renovable          Renovable  2021-04-01T00:00:00.000+02:00
# 4       Renovable          Renovable  2021-05-01T00:00:00.000+02:00
#
#           Valor
# 0  1.256107e+07
# 1  1.235994e+07
# 2  1.179999e+07
# 3  9.240647e+06
# 4  1.043336e+07
